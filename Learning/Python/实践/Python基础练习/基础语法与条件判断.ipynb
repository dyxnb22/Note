# %%
name = "Tom"
age = 18
price = 19.9
is_ok = True

# %%
print(name, age, price, is_ok)
# Out:
# Tom 18 19.9 True

# %%
print(type(name), type(age), type(price), type(is_ok))
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>

# %%
if age > 18 and not is_ok:
    print("You are an adult.")
